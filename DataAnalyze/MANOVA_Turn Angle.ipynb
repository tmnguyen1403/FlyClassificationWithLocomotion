# %%
import pandas as pd
from statsmodels.multivariate.manova import MANOVA

# %%
df = pd.read_excel("Combined Data in Turn Angle with Time Blocks.xlsx")

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
df
# Out:
#      Fly_Type         Period  Turn_Angle
# 0     cantonS   0 - 2.5 mins     0.00000
# 1     cantonS   0 - 2.5 mins     0.47300
# 2     cantonS   0 - 2.5 mins     0.41351
# 3     cantonS   0 - 2.5 mins     1.42849
# 4     cantonS   0 - 2.5 mins     0.30995
# ...       ...            ...         ...
# 2395    W1118  7.5 - 10 mins     0.30888
# 2396    W1118  7.5 - 10 mins     1.80332
# 2397    W1118  7.5 - 10 mins     1.03358
# 2398    W1118  7.5 - 10 mins     0.05610
# 2399    W1118  7.5 - 10 mins     0.00000
#
# [2400 rows x 3 columns]

# %%
maov = MANOVA.from_formula('Period * Fly_Type ~ Turn_Angle', data=df)

# %%
print(maov.mv_test())
# Out:
#                                   Multivariate linear model
# ...
#
# ----------------------------------------------------------------------------------------------
#        Intercept                Value          Num DF   Den DF          F Value         Pr > F
# ----------------------------------------------------------------------------------------------
#           Wilks' lambda               -0.0000 16.0000 2383.0000 -37264159416749768.0000 1.0000
#          Pillai's trace                1.0000 16.0000 2383.0000 -37264159416749776.0000 1.0000
#  Hotelling-Lawley trace -250199979298361.8750 16.0000 2383.0000 -37264159416749776.0000 1.0000
#     Roy's greatest root -250199979298361.8750 16.0000 2383.0000 -37264159416749768.0000 1.0000
# ----------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# We can conclude that there is an association between turn angle and the relationship between period and genotype

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import statsmodels.api as sm

# %%
model_lin = sm.OLS.from_formula("Turn_Angle ~ Period * Fly_Type", data=df)
result_lin = model_lin.fit()
result_lin.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Turn_Angle   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     22.78
# Date:                Thu, 15 Apr 2021   Prob (F-statistic):           3.41e-59
# Time:                        09:36:33   Log-Likelihood:                -3508.0
# No. Observations:                2400   AIC:                             7048.
# Df Residuals:                    2384   BIC:                             7141.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# We reject the null hypothesis in this analysis is that a Turn Angle has no effect on Period and Fly Type at alpha level .05 because the p-values are all less than .05
