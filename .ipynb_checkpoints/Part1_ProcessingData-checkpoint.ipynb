# %%
# Task
# Prepare the figures with legends, titles interpreting the result
# Table - captions, titles
# Write the methods in past tense

# Look at the accuracy on each of genotypes, confusion matrix, to get the accuracy

#Figure 1: Original Data -> Turn Angle, Distance
#Table 1: Result of binary classification
#Table 2: Result of multi classification

# %% [markdown]
# # Require Libraries For Data Processing

# %%
import os
import math
from queue import LifoQueue

# %% [markdown]
# # Require Libraries For Model Training

# %%
import sklearn
import imblearn.over_sampling
import numpy as np

# %% [markdown]
# # I. DATA PROCESSING

# %% [markdown]
# # 1. Process trajectories data

# %% [markdown]
# ## Data Description
# Time step = 0.033
# The number of row in a file may vary.
#
# | Time | X   | Y |
# | --- | --- | --- |
# |0.00| -26.98|3.0417|
# |0.033|-2.7269|2.995|
# |0.066|2.7542|2.995|
# |...|...|...|
# |598.97|0.2451|-4.3645|

# %%
class FileManager:
    
    def __init__(self):
        self.ROOT = "./Trajectories/8.4"
        self.FILE_LOCATION = "XY"
        self.OUTPUT_FOLDER = "./FilterData"
        self.inputPath = ""
        self.outputPath = ""
    
    def setRootPath(self, path):
        self.ROOT = path

    def getFilesFrom(self, flyFolder):
        myPath = os.path.join(self.ROOT, flyFolder, self.FILE_LOCATION)
        #default input path
        self.inputPath = myPath
        #default outputPath
        self.outputPath = os.path.join(self.OUTPUT_FOLDER, flyFolder)
        return os.listdir(myPath)
    
    def makePathFor(self, flyFile):
        myPath = os.path.join(self.inputPath, flyFile)
        return myPath
    
    def makeSavePathFor(self, flyFile):
        myPath = os.path.join(self.outputPath, flyFile)
        return myPath
    
    def saveFile(self, flyFile, data):
        outPath = self.makeSavePathFor(flyFile)
        try:
            with open(outPath,"w") as f:
                for line in data:
                    line_str=[str(i) for i in line]
                    line_csv="\t".join(line_str)
                    f.write(line_csv + "\n")
            print(f'saving to {outPath} complete')
        except Exception as e:
            print(f'Error saving file {outPath}\n')
            print(f'{e}')
            
    def logError(self, error):
        try:
            with open(self.errorPath,"a") as f:
                f.write(error)
        except Exception as e:
            print(f'Error writing log to file {self.errorPath}\n')
            print(f'{e}')

# %% [markdown]
# ### a. Select genotypes
# Genotypes' folders are named after them, so please be aware of not mispelling the name. Programmactically, you can retrieve the name of all folder using `os.listdir(PATH)` but this should be use cautiously if you have extra files in your path.

# %%
GENOTYPES = ["cantonS","W1118","norpA7","rutabaga"]

# %% [markdown]
# ### b. Selecting data from each genotype

# %% [markdown]
# For this research, we only choose to use the recorded data with the time interval of 1.0 second. You need to run the code below to extract the data.

# %%
totalTime = 10 * 60 # 10 mins * 60 seconds
timeInterval = 0.2 #second
fileManager = FileManager()
fileManager.OUTPUT_FOLDER = "./SmallIntervalData"

# %%
# !mkdir $fileManager.OUTPUT_FOLDER
#Create result folders
resultFolder = fileManager.outputPath

for folder in GENOTYPES:
    path = os.path.join(fileManager.OUTPUT_FOLDER, folder)
    # !mkdir $path

# %%
timeline = [0,0.033,0.066,0.1,0.133,0.166,0.2]
r = timeline.index(min(timeline, key=lambda x: abs(x - 0.4)))
print(r)
print(timeline[6])
# Out:
# 6
# 0.2

# %% [markdown]
# * Estimated runtime for the code below - [10 -15] minutes

# %%
#iterrative through each genotype's folders
for genotype in GENOTYPES:
    index = 0
    flyFiles = fileManager.getFilesFrom(genotype)
    
    #iterrative throuch all fly's records in the selected genotype
    for fly in flyFiles:
        try:
            myPath = fileManager.makePathFor(fly)
            with open(myPath, "r") as data:
                print(f'Processing file: {myPath}')
                db = data.readlines()
                #run your function here
                data=[]
                timeline=[]
                for line in db:
                    timeline.append(float(line.strip("\n").split("\t")[0]))
                counter = 0
                while counter < totalTime:
                    indexOfCounter = timeline.index(min(timeline, key= lambda x: abs(x - counter)))
                    data.append(db[indexOfCounter].strip("\n").split("\t"))
                    counter += timeInterval
                fileManager.saveFile(fly, data)
                print("")

        except Exception as e:
            print(f'Error processing file {myPath}\n')
            print(f'{e}')
# Out:
# Processing file: ./Trajectories/8.4/cantonS/XY/run238.txt
# saving to ./SmallIntervalData/cantonS/run238.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run204.txt
# saving to ./SmallIntervalData/cantonS/run204.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run210.txt
# saving to ./SmallIntervalData/cantonS/run210.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run199.txt
# saving to ./SmallIntervalData/cantonS/run199.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run172.txt
# saving to ./SmallIntervalData/cantonS/run172.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run166.txt
# saving to ./SmallIntervalData/cantonS/run166.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run94.txt
# saving to ./SmallIntervalData/cantonS/run94.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run80.txt
# saving to ./SmallIntervalData/cantonS/run80.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run57.txt
# saving to ./SmallIntervalData/cantonS/run57.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run43.txt
# saving to ./SmallIntervalData/cantonS/run43.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run42.txt
# saving to ./SmallIntervalData/cantonS/run42.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run56.txt
# saving to ./SmallIntervalData/cantonS/run56.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run81.txt
# saving to ./SmallIntervalData/cantonS/run81.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run95.txt
# saving to ./SmallIntervalData/cantonS/run95.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run167.txt
# saving to ./SmallIntervalData/cantonS/run167.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run173.txt
# saving to ./SmallIntervalData/cantonS/run173.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run198.txt
# saving to ./SmallIntervalData/cantonS/run198.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run211.txt
# saving to ./SmallIntervalData/cantonS/run211.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run205.txt
# saving to ./SmallIntervalData/cantonS/run205.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run239.txt
# saving to ./SmallIntervalData/cantonS/run239.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run213.txt
# saving to ./SmallIntervalData/cantonS/run213.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run207.txt
# saving to ./SmallIntervalData/cantonS/run207.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run159.txt
# saving to ./SmallIntervalData/cantonS/run159.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run165.txt
# saving to ./SmallIntervalData/cantonS/run165.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run171.txt
# saving to ./SmallIntervalData/cantonS/run171.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run83.txt
# saving to ./SmallIntervalData/cantonS/run83.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run97.txt
# saving to ./SmallIntervalData/cantonS/run97.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run40.txt
# saving to ./SmallIntervalData/cantonS/run40.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run54.txt
# saving to ./SmallIntervalData/cantonS/run54.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run68.txt
# saving to ./SmallIntervalData/cantonS/run68.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run69.txt
# saving to ./SmallIntervalData/cantonS/run69.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run55.txt
# saving to ./SmallIntervalData/cantonS/run55.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run41.txt
# saving to ./SmallIntervalData/cantonS/run41.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run96.txt
# saving to ./SmallIntervalData/cantonS/run96.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run82.txt
# saving to ./SmallIntervalData/cantonS/run82.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run170.txt
# saving to ./SmallIntervalData/cantonS/run170.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run164.txt
# saving to ./SmallIntervalData/cantonS/run164.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run158.txt
# saving to ./SmallIntervalData/cantonS/run158.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run206.txt
# saving to ./SmallIntervalData/cantonS/run206.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run212.txt
# saving to ./SmallIntervalData/cantonS/run212.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run216.txt
# saving to ./SmallIntervalData/cantonS/run216.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run202.txt
# saving to ./SmallIntervalData/cantonS/run202.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run160.txt
# saving to ./SmallIntervalData/cantonS/run160.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run174.txt
# saving to ./SmallIntervalData/cantonS/run174.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run148.txt
# saving to ./SmallIntervalData/cantonS/run148.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run86.txt
# saving to ./SmallIntervalData/cantonS/run86.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run92.txt
# saving to ./SmallIntervalData/cantonS/run92.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run79.txt
# saving to ./SmallIntervalData/cantonS/run79.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run45.txt
# saving to ./SmallIntervalData/cantonS/run45.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run51.txt
# saving to ./SmallIntervalData/cantonS/run51.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run50.txt
# saving to ./SmallIntervalData/cantonS/run50.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run44.txt
# saving to ./SmallIntervalData/cantonS/run44.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run78.txt
# saving to ./SmallIntervalData/cantonS/run78.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run93.txt
# saving to ./SmallIntervalData/cantonS/run93.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run87.txt
# saving to ./SmallIntervalData/cantonS/run87.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run149.txt
# saving to ./SmallIntervalData/cantonS/run149.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run175.txt
# saving to ./SmallIntervalData/cantonS/run175.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run161.txt
# saving to ./SmallIntervalData/cantonS/run161.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run203.txt
# saving to ./SmallIntervalData/cantonS/run203.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run217.txt
# saving to ./SmallIntervalData/cantonS/run217.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run201.txt
# saving to ./SmallIntervalData/cantonS/run201.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run215.txt
# saving to ./SmallIntervalData/cantonS/run215.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run229.txt
# saving to ./SmallIntervalData/cantonS/run229.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run188.txt
# saving to ./SmallIntervalData/cantonS/run188.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run177.txt
# saving to ./SmallIntervalData/cantonS/run177.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run163.txt
# saving to ./SmallIntervalData/cantonS/run163.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run91.txt
# saving to ./SmallIntervalData/cantonS/run91.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run85.txt
# saving to ./SmallIntervalData/cantonS/run85.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run52.txt
# saving to ./SmallIntervalData/cantonS/run52.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run46.txt
# saving to ./SmallIntervalData/cantonS/run46.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run47.txt
# saving to ./SmallIntervalData/cantonS/run47.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run53.txt
# saving to ./SmallIntervalData/cantonS/run53.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run84.txt
# saving to ./SmallIntervalData/cantonS/run84.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run90.txt
# saving to ./SmallIntervalData/cantonS/run90.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run162.txt
# saving to ./SmallIntervalData/cantonS/run162.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run176.txt
# saving to ./SmallIntervalData/cantonS/run176.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run189.txt
# saving to ./SmallIntervalData/cantonS/run189.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run228.txt
# saving to ./SmallIntervalData/cantonS/run228.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run214.txt
# saving to ./SmallIntervalData/cantonS/run214.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run200.txt
# saving to ./SmallIntervalData/cantonS/run200.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run267.txt
# saving to ./SmallIntervalData/cantonS/run267.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run273.txt
# saving to ./SmallIntervalData/cantonS/run273.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run139.txt
# saving to ./SmallIntervalData/cantonS/run139.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run111.txt
# saving to ./SmallIntervalData/cantonS/run111.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run105.txt
# saving to ./SmallIntervalData/cantonS/run105.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run34.txt
# saving to ./SmallIntervalData/cantonS/run34.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run20.txt
# saving to ./SmallIntervalData/cantonS/run20.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run21.txt
# saving to ./SmallIntervalData/cantonS/run21.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run35.txt
# saving to ./SmallIntervalData/cantonS/run35.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run104.txt
# saving to ./SmallIntervalData/cantonS/run104.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run110.txt
# saving to ./SmallIntervalData/cantonS/run110.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run138.txt
# saving to ./SmallIntervalData/cantonS/run138.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run272.txt
# saving to ./SmallIntervalData/cantonS/run272.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run266.txt
# saving to ./SmallIntervalData/cantonS/run266.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run258.txt
# saving to ./SmallIntervalData/cantonS/run258.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run270.txt
# saving to ./SmallIntervalData/cantonS/run270.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run264.txt
# saving to ./SmallIntervalData/cantonS/run264.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run106.txt
# saving to ./SmallIntervalData/cantonS/run106.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run112.txt
# saving to ./SmallIntervalData/cantonS/run112.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run23.txt
# saving to ./SmallIntervalData/cantonS/run23.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run37.txt
# saving to ./SmallIntervalData/cantonS/run37.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run36.txt
# saving to ./SmallIntervalData/cantonS/run36.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run22.txt
# saving to ./SmallIntervalData/cantonS/run22.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run113.txt
# saving to ./SmallIntervalData/cantonS/run113.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run107.txt
# saving to ./SmallIntervalData/cantonS/run107.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run265.txt
# saving to ./SmallIntervalData/cantonS/run265.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run271.txt
# saving to ./SmallIntervalData/cantonS/run271.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run259.txt
# saving to ./SmallIntervalData/cantonS/run259.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run275.txt
# saving to ./SmallIntervalData/cantonS/run275.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run261.txt
# saving to ./SmallIntervalData/cantonS/run261.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run249.txt
# saving to ./SmallIntervalData/cantonS/run249.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run9.txt
# saving to ./SmallIntervalData/cantonS/run9.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run103.txt
# saving to ./SmallIntervalData/cantonS/run103.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run117.txt
# saving to ./SmallIntervalData/cantonS/run117.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run26.txt
# saving to ./SmallIntervalData/cantonS/run26.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run32.txt
# saving to ./SmallIntervalData/cantonS/run32.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run33.txt
# saving to ./SmallIntervalData/cantonS/run33.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run27.txt
# saving to ./SmallIntervalData/cantonS/run27.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run116.txt
# saving to ./SmallIntervalData/cantonS/run116.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run102.txt
# saving to ./SmallIntervalData/cantonS/run102.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run8.txt
# saving to ./SmallIntervalData/cantonS/run8.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run248.txt
# saving to ./SmallIntervalData/cantonS/run248.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run260.txt
# saving to ./SmallIntervalData/cantonS/run260.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run274.txt
# saving to ./SmallIntervalData/cantonS/run274.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run262.txt
# saving to ./SmallIntervalData/cantonS/run262.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run276.txt
# saving to ./SmallIntervalData/cantonS/run276.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run114.txt
# saving to ./SmallIntervalData/cantonS/run114.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run100.txt
# saving to ./SmallIntervalData/cantonS/run100.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run128.txt
# saving to ./SmallIntervalData/cantonS/run128.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run19.txt
# saving to ./SmallIntervalData/cantonS/run19.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run31.txt
# saving to ./SmallIntervalData/cantonS/run31.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run25.txt
# saving to ./SmallIntervalData/cantonS/run25.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run30.txt
# saving to ./SmallIntervalData/cantonS/run30.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run18.txt
# saving to ./SmallIntervalData/cantonS/run18.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run129.txt
# saving to ./SmallIntervalData/cantonS/run129.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run101.txt
# saving to ./SmallIntervalData/cantonS/run101.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run115.txt
# saving to ./SmallIntervalData/cantonS/run115.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run263.txt
# saving to ./SmallIntervalData/cantonS/run263.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run246.txt
# saving to ./SmallIntervalData/cantonS/run246.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run252.txt
# saving to ./SmallIntervalData/cantonS/run252.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run6.txt
# saving to ./SmallIntervalData/cantonS/run6.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run118.txt
# saving to ./SmallIntervalData/cantonS/run118.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run130.txt
# saving to ./SmallIntervalData/cantonS/run130.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run124.txt
# saving to ./SmallIntervalData/cantonS/run124.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run15.txt
# saving to ./SmallIntervalData/cantonS/run15.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run29.txt
# saving to ./SmallIntervalData/cantonS/run29.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run28.txt
# saving to ./SmallIntervalData/cantonS/run28.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run14.txt
# saving to ./SmallIntervalData/cantonS/run14.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run125.txt
# saving to ./SmallIntervalData/cantonS/run125.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run131.txt
# saving to ./SmallIntervalData/cantonS/run131.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run119.txt
# saving to ./SmallIntervalData/cantonS/run119.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run7.txt
# saving to ./SmallIntervalData/cantonS/run7.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run253.txt
# saving to ./SmallIntervalData/cantonS/run253.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run247.txt
# saving to ./SmallIntervalData/cantonS/run247.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run251.txt
# saving to ./SmallIntervalData/cantonS/run251.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run245.txt
# saving to ./SmallIntervalData/cantonS/run245.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run5.txt
# saving to ./SmallIntervalData/cantonS/run5.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run127.txt
# saving to ./SmallIntervalData/cantonS/run127.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run133.txt
# saving to ./SmallIntervalData/cantonS/run133.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run16.txt
# saving to ./SmallIntervalData/cantonS/run16.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run17.txt
# saving to ./SmallIntervalData/cantonS/run17.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run132.txt
# saving to ./SmallIntervalData/cantonS/run132.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run126.txt
# saving to ./SmallIntervalData/cantonS/run126.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run4.txt
# saving to ./SmallIntervalData/cantonS/run4.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run244.txt
# saving to ./SmallIntervalData/cantonS/run244.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run250.txt
# saving to ./SmallIntervalData/cantonS/run250.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run254.txt
# saving to ./SmallIntervalData/cantonS/run254.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run240.txt
# saving to ./SmallIntervalData/cantonS/run240.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run268.txt
# saving to ./SmallIntervalData/cantonS/run268.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run122.txt
# saving to ./SmallIntervalData/cantonS/run122.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run136.txt
# saving to ./SmallIntervalData/cantonS/run136.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run13.txt
# saving to ./SmallIntervalData/cantonS/run13.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run12.txt
# saving to ./SmallIntervalData/cantonS/run12.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run137.txt
# saving to ./SmallIntervalData/cantonS/run137.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run123.txt
# saving to ./SmallIntervalData/cantonS/run123.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run1.txt
# saving to ./SmallIntervalData/cantonS/run1.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run269.txt
# saving to ./SmallIntervalData/cantonS/run269.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run241.txt
# saving to ./SmallIntervalData/cantonS/run241.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run255.txt
# saving to ./SmallIntervalData/cantonS/run255.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run243.txt
# saving to ./SmallIntervalData/cantonS/run243.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run257.txt
# saving to ./SmallIntervalData/cantonS/run257.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run3.txt
# saving to ./SmallIntervalData/cantonS/run3.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run135.txt
# saving to ./SmallIntervalData/cantonS/run135.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run121.txt
# saving to ./SmallIntervalData/cantonS/run121.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run109.txt
# saving to ./SmallIntervalData/cantonS/run109.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run38.txt
# saving to ./SmallIntervalData/cantonS/run38.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run10.txt
# saving to ./SmallIntervalData/cantonS/run10.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run11.txt
# saving to ./SmallIntervalData/cantonS/run11.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run39.txt
# saving to ./SmallIntervalData/cantonS/run39.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run108.txt
# saving to ./SmallIntervalData/cantonS/run108.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run120.txt
# saving to ./SmallIntervalData/cantonS/run120.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run134.txt
# saving to ./SmallIntervalData/cantonS/run134.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run2.txt
# saving to ./SmallIntervalData/cantonS/run2.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run256.txt
# saving to ./SmallIntervalData/cantonS/run256.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run242.txt
# saving to ./SmallIntervalData/cantonS/run242.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run219.txt
# saving to ./SmallIntervalData/cantonS/run219.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run225.txt
# saving to ./SmallIntervalData/cantonS/run225.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run231.txt
# saving to ./SmallIntervalData/cantonS/run231.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run190.txt
# saving to ./SmallIntervalData/cantonS/run190.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run184.txt
# saving to ./SmallIntervalData/cantonS/run184.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run153.txt
# saving to ./SmallIntervalData/cantonS/run153.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run147.txt
# saving to ./SmallIntervalData/cantonS/run147.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run89.txt
# saving to ./SmallIntervalData/cantonS/run89.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run76.txt
# saving to ./SmallIntervalData/cantonS/run76.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run62.txt
# saving to ./SmallIntervalData/cantonS/run62.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run63.txt
# saving to ./SmallIntervalData/cantonS/run63.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run77.txt
# saving to ./SmallIntervalData/cantonS/run77.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run88.txt
# saving to ./SmallIntervalData/cantonS/run88.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run146.txt
# saving to ./SmallIntervalData/cantonS/run146.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run152.txt
# saving to ./SmallIntervalData/cantonS/run152.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run185.txt
# saving to ./SmallIntervalData/cantonS/run185.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run191.txt
# saving to ./SmallIntervalData/cantonS/run191.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run230.txt
# saving to ./SmallIntervalData/cantonS/run230.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run224.txt
# saving to ./SmallIntervalData/cantonS/run224.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run218.txt
# saving to ./SmallIntervalData/cantonS/run218.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run232.txt
# saving to ./SmallIntervalData/cantonS/run232.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run226.txt
# saving to ./SmallIntervalData/cantonS/run226.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run187.txt
# saving to ./SmallIntervalData/cantonS/run187.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run193.txt
# saving to ./SmallIntervalData/cantonS/run193.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run178.txt
# saving to ./SmallIntervalData/cantonS/run178.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run144.txt
# saving to ./SmallIntervalData/cantonS/run144.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run150.txt
# saving to ./SmallIntervalData/cantonS/run150.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run61.txt
# saving to ./SmallIntervalData/cantonS/run61.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run75.txt
# saving to ./SmallIntervalData/cantonS/run75.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run49.txt
# saving to ./SmallIntervalData/cantonS/run49.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run48.txt
# saving to ./SmallIntervalData/cantonS/run48.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run74.txt
# saving to ./SmallIntervalData/cantonS/run74.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run60.txt
# saving to ./SmallIntervalData/cantonS/run60.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run151.txt
# saving to ./SmallIntervalData/cantonS/run151.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run145.txt
# saving to ./SmallIntervalData/cantonS/run145.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run179.txt
# saving to ./SmallIntervalData/cantonS/run179.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run192.txt
# saving to ./SmallIntervalData/cantonS/run192.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run186.txt
# saving to ./SmallIntervalData/cantonS/run186.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run227.txt
# saving to ./SmallIntervalData/cantonS/run227.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run233.txt
# saving to ./SmallIntervalData/cantonS/run233.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run237.txt
# saving to ./SmallIntervalData/cantonS/run237.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run223.txt
# saving to ./SmallIntervalData/cantonS/run223.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run182.txt
# saving to ./SmallIntervalData/cantonS/run182.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run196.txt
# saving to ./SmallIntervalData/cantonS/run196.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run141.txt
# saving to ./SmallIntervalData/cantonS/run141.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run155.txt
# saving to ./SmallIntervalData/cantonS/run155.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run169.txt
# saving to ./SmallIntervalData/cantonS/run169.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run58.txt
# saving to ./SmallIntervalData/cantonS/run58.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run64.txt
# saving to ./SmallIntervalData/cantonS/run64.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run70.txt
# saving to ./SmallIntervalData/cantonS/run70.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run71.txt
# saving to ./SmallIntervalData/cantonS/run71.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run65.txt
# saving to ./SmallIntervalData/cantonS/run65.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run59.txt
# saving to ./SmallIntervalData/cantonS/run59.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run168.txt
# saving to ./SmallIntervalData/cantonS/run168.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run154.txt
# saving to ./SmallIntervalData/cantonS/run154.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run140.txt
# saving to ./SmallIntervalData/cantonS/run140.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run197.txt
# saving to ./SmallIntervalData/cantonS/run197.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run183.txt
# saving to ./SmallIntervalData/cantonS/run183.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run222.txt
# saving to ./SmallIntervalData/cantonS/run222.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run236.txt
# saving to ./SmallIntervalData/cantonS/run236.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run220.txt
# saving to ./SmallIntervalData/cantonS/run220.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run234.txt
# saving to ./SmallIntervalData/cantonS/run234.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run208.txt
# saving to ./SmallIntervalData/cantonS/run208.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run195.txt
# saving to ./SmallIntervalData/cantonS/run195.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run181.txt
# saving to ./SmallIntervalData/cantonS/run181.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run156.txt
# saving to ./SmallIntervalData/cantonS/run156.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run142.txt
# saving to ./SmallIntervalData/cantonS/run142.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run98.txt
# saving to ./SmallIntervalData/cantonS/run98.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run73.txt
# saving to ./SmallIntervalData/cantonS/run73.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run67.txt
# saving to ./SmallIntervalData/cantonS/run67.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run66.txt
# saving to ./SmallIntervalData/cantonS/run66.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run72.txt
# saving to ./SmallIntervalData/cantonS/run72.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run99.txt
# saving to ./SmallIntervalData/cantonS/run99.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run143.txt
# saving to ./SmallIntervalData/cantonS/run143.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run157.txt
# saving to ./SmallIntervalData/cantonS/run157.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run180.txt
# saving to ./SmallIntervalData/cantonS/run180.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run194.txt
# saving to ./SmallIntervalData/cantonS/run194.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run209.txt
# saving to ./SmallIntervalData/cantonS/run209.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run235.txt
# saving to ./SmallIntervalData/cantonS/run235.txt complete
#
# Processing file: ./Trajectories/8.4/cantonS/XY/run221.txt
# saving to ./SmallIntervalData/cantonS/run221.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run94.txt
# saving to ./SmallIntervalData/W1118/run94.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run80.txt
# saving to ./SmallIntervalData/W1118/run80.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run57.txt
# saving to ./SmallIntervalData/W1118/run57.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run43.txt
# saving to ./SmallIntervalData/W1118/run43.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run42.txt
# saving to ./SmallIntervalData/W1118/run42.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run56.txt
# saving to ./SmallIntervalData/W1118/run56.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run81.txt
# saving to ./SmallIntervalData/W1118/run81.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run95.txt
# saving to ./SmallIntervalData/W1118/run95.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run83.txt
# saving to ./SmallIntervalData/W1118/run83.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run97.txt
# saving to ./SmallIntervalData/W1118/run97.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run40.txt
# saving to ./SmallIntervalData/W1118/run40.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run54.txt
# saving to ./SmallIntervalData/W1118/run54.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run68.txt
# saving to ./SmallIntervalData/W1118/run68.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run69.txt
# saving to ./SmallIntervalData/W1118/run69.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run55.txt
# saving to ./SmallIntervalData/W1118/run55.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run41.txt
# saving to ./SmallIntervalData/W1118/run41.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run96.txt
# saving to ./SmallIntervalData/W1118/run96.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run82.txt
# saving to ./SmallIntervalData/W1118/run82.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run86.txt
# saving to ./SmallIntervalData/W1118/run86.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run92.txt
# saving to ./SmallIntervalData/W1118/run92.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run79.txt
# saving to ./SmallIntervalData/W1118/run79.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run45.txt
# saving to ./SmallIntervalData/W1118/run45.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run51.txt
# saving to ./SmallIntervalData/W1118/run51.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run50.txt
# saving to ./SmallIntervalData/W1118/run50.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run44.txt
# saving to ./SmallIntervalData/W1118/run44.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run78.txt
# saving to ./SmallIntervalData/W1118/run78.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run93.txt
# saving to ./SmallIntervalData/W1118/run93.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run87.txt
# saving to ./SmallIntervalData/W1118/run87.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run91.txt
# saving to ./SmallIntervalData/W1118/run91.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run85.txt
# saving to ./SmallIntervalData/W1118/run85.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run52.txt
# saving to ./SmallIntervalData/W1118/run52.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run46.txt
# saving to ./SmallIntervalData/W1118/run46.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run47.txt
# saving to ./SmallIntervalData/W1118/run47.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run53.txt
# saving to ./SmallIntervalData/W1118/run53.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run84.txt
# saving to ./SmallIntervalData/W1118/run84.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run90.txt
# saving to ./SmallIntervalData/W1118/run90.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run111.txt
# saving to ./SmallIntervalData/W1118/run111.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run105.txt
# saving to ./SmallIntervalData/W1118/run105.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run34.txt
# saving to ./SmallIntervalData/W1118/run34.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run20.txt
# saving to ./SmallIntervalData/W1118/run20.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run21.txt
# saving to ./SmallIntervalData/W1118/run21.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run35.txt
# saving to ./SmallIntervalData/W1118/run35.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run104.txt
# saving to ./SmallIntervalData/W1118/run104.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run106.txt
# saving to ./SmallIntervalData/W1118/run106.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run112.txt
# saving to ./SmallIntervalData/W1118/run112.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run23.txt
# saving to ./SmallIntervalData/W1118/run23.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run37.txt
# saving to ./SmallIntervalData/W1118/run37.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run36.txt
# saving to ./SmallIntervalData/W1118/run36.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run22.txt
# saving to ./SmallIntervalData/W1118/run22.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run113.txt
# saving to ./SmallIntervalData/W1118/run113.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run107.txt
# saving to ./SmallIntervalData/W1118/run107.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run9.txt
# saving to ./SmallIntervalData/W1118/run9.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run103.txt
# saving to ./SmallIntervalData/W1118/run103.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run117.txt
# saving to ./SmallIntervalData/W1118/run117.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run26.txt
# saving to ./SmallIntervalData/W1118/run26.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run32.txt
# saving to ./SmallIntervalData/W1118/run32.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run33.txt
# saving to ./SmallIntervalData/W1118/run33.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run27.txt
# saving to ./SmallIntervalData/W1118/run27.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run116.txt
# saving to ./SmallIntervalData/W1118/run116.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run102.txt
# saving to ./SmallIntervalData/W1118/run102.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run8.txt
# saving to ./SmallIntervalData/W1118/run8.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run114.txt
# saving to ./SmallIntervalData/W1118/run114.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run100.txt
# saving to ./SmallIntervalData/W1118/run100.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run19.txt
# saving to ./SmallIntervalData/W1118/run19.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run31.txt
# saving to ./SmallIntervalData/W1118/run31.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run25.txt
# saving to ./SmallIntervalData/W1118/run25.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run24.txt
# saving to ./SmallIntervalData/W1118/run24.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run30.txt
# saving to ./SmallIntervalData/W1118/run30.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run18.txt
# saving to ./SmallIntervalData/W1118/run18.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run101.txt
# saving to ./SmallIntervalData/W1118/run101.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run115.txt
# saving to ./SmallIntervalData/W1118/run115.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run6.txt
# saving to ./SmallIntervalData/W1118/run6.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run118.txt
# saving to ./SmallIntervalData/W1118/run118.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run15.txt
# saving to ./SmallIntervalData/W1118/run15.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run29.txt
# saving to ./SmallIntervalData/W1118/run29.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run28.txt
# saving to ./SmallIntervalData/W1118/run28.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run14.txt
# saving to ./SmallIntervalData/W1118/run14.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run119.txt
# saving to ./SmallIntervalData/W1118/run119.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run7.txt
# saving to ./SmallIntervalData/W1118/run7.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run5.txt
# saving to ./SmallIntervalData/W1118/run5.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run16.txt
# saving to ./SmallIntervalData/W1118/run16.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run17.txt
# saving to ./SmallIntervalData/W1118/run17.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run4.txt
# saving to ./SmallIntervalData/W1118/run4.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run13.txt
# saving to ./SmallIntervalData/W1118/run13.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run12.txt
# saving to ./SmallIntervalData/W1118/run12.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run1.txt
# saving to ./SmallIntervalData/W1118/run1.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run3.txt
# saving to ./SmallIntervalData/W1118/run3.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run109.txt
# saving to ./SmallIntervalData/W1118/run109.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run38.txt
# saving to ./SmallIntervalData/W1118/run38.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run10.txt
# saving to ./SmallIntervalData/W1118/run10.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run11.txt
# saving to ./SmallIntervalData/W1118/run11.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run39.txt
# saving to ./SmallIntervalData/W1118/run39.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run108.txt
# saving to ./SmallIntervalData/W1118/run108.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run120.txt
# saving to ./SmallIntervalData/W1118/run120.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run2.txt
# saving to ./SmallIntervalData/W1118/run2.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run89.txt
# saving to ./SmallIntervalData/W1118/run89.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run76.txt
# saving to ./SmallIntervalData/W1118/run76.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run62.txt
# saving to ./SmallIntervalData/W1118/run62.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run63.txt
# saving to ./SmallIntervalData/W1118/run63.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run77.txt
# saving to ./SmallIntervalData/W1118/run77.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run88.txt
# saving to ./SmallIntervalData/W1118/run88.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run61.txt
# saving to ./SmallIntervalData/W1118/run61.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run75.txt
# saving to ./SmallIntervalData/W1118/run75.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run49.txt
# saving to ./SmallIntervalData/W1118/run49.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run48.txt
# saving to ./SmallIntervalData/W1118/run48.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run74.txt
# saving to ./SmallIntervalData/W1118/run74.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run60.txt
# saving to ./SmallIntervalData/W1118/run60.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run58.txt
# saving to ./SmallIntervalData/W1118/run58.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run64.txt
# saving to ./SmallIntervalData/W1118/run64.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run70.txt
# saving to ./SmallIntervalData/W1118/run70.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run71.txt
# saving to ./SmallIntervalData/W1118/run71.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run65.txt
# saving to ./SmallIntervalData/W1118/run65.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run59.txt
# saving to ./SmallIntervalData/W1118/run59.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run98.txt
# saving to ./SmallIntervalData/W1118/run98.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run73.txt
# saving to ./SmallIntervalData/W1118/run73.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run67.txt
# saving to ./SmallIntervalData/W1118/run67.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run66.txt
# saving to ./SmallIntervalData/W1118/run66.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run72.txt
# saving to ./SmallIntervalData/W1118/run72.txt complete
#
# Processing file: ./Trajectories/8.4/W1118/XY/run99.txt
# saving to ./SmallIntervalData/W1118/run99.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run94.txt
# saving to ./SmallIntervalData/norpA7/run94.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run80.txt
# saving to ./SmallIntervalData/norpA7/run80.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run57.txt
# saving to ./SmallIntervalData/norpA7/run57.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run43.txt
# saving to ./SmallIntervalData/norpA7/run43.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run42.txt
# saving to ./SmallIntervalData/norpA7/run42.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run56.txt
# saving to ./SmallIntervalData/norpA7/run56.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run81.txt
# saving to ./SmallIntervalData/norpA7/run81.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run95.txt
# saving to ./SmallIntervalData/norpA7/run95.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run83.txt
# saving to ./SmallIntervalData/norpA7/run83.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run97.txt
# saving to ./SmallIntervalData/norpA7/run97.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run40.txt
# saving to ./SmallIntervalData/norpA7/run40.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run54.txt
# saving to ./SmallIntervalData/norpA7/run54.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run68.txt
# saving to ./SmallIntervalData/norpA7/run68.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run69.txt
# saving to ./SmallIntervalData/norpA7/run69.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run55.txt
# saving to ./SmallIntervalData/norpA7/run55.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run41.txt
# saving to ./SmallIntervalData/norpA7/run41.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run96.txt
# saving to ./SmallIntervalData/norpA7/run96.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run82.txt
# saving to ./SmallIntervalData/norpA7/run82.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run86.txt
# saving to ./SmallIntervalData/norpA7/run86.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run92.txt
# saving to ./SmallIntervalData/norpA7/run92.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run79.txt
# saving to ./SmallIntervalData/norpA7/run79.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run45.txt
# saving to ./SmallIntervalData/norpA7/run45.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run51.txt
# saving to ./SmallIntervalData/norpA7/run51.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run50.txt
# saving to ./SmallIntervalData/norpA7/run50.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run44.txt
# ...
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run98.txt
# saving to ./SmallIntervalData/norpA7/run98.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run73.txt
# saving to ./SmallIntervalData/norpA7/run73.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run67.txt
# saving to ./SmallIntervalData/norpA7/run67.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run66.txt
# saving to ./SmallIntervalData/norpA7/run66.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run72.txt
# saving to ./SmallIntervalData/norpA7/run72.txt complete
#
# Processing file: ./Trajectories/8.4/norpA7/XY/run99.txt
# saving to ./SmallIntervalData/norpA7/run99.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    50).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    50).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    51).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    51).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    19).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    19).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    18).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    18).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     1).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     1).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    27).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    27).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    26).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    26).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    13).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    13).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    12).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    12).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    47).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    47).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    46).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    46).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    30).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    30).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    31).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    31).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    40).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    40).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    41).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    41).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    37).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    37).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    36).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    36).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    57).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    57).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    56).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    56).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     6).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     6).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     7).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     7).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    20).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    20).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    21).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    21).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    14).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    14).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    15).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    15).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    63).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    63).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    62).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    62).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    39).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    39).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    38).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    38).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    44).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    44).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    45).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    45).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    33).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    33).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    32).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    32).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    10).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    10).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    11).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    11).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    59).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    59).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    58).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    58).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     8).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     8).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     9).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     9).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    53).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    53).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    52).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    52).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     2).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     2).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     3).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     3).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    24).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    24).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    25).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    25).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    17).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    17).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    16).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    16).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    29).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    29).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    28).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    28).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    60).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    60).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    54).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    54).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    55).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    55).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     5).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     5).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     4).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     4).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    23).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    23).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    22).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    22).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    49).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    49).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    48).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    48).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    43).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    43).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    42).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    42).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    34).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    34).xls.txt complete
#
# Processing file: ./Trajectories/8.4/rutabaga/XY/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    35).xls.txt
# saving to ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    35).xls.txt complete

# %% [markdown]
# # 2. Convert (x,y) data to (distance, turnangle)

# %% [markdown]
# ## Location Class
# This class is used to calculate distance and turn angle

# %%
DISTANCE_THRESHOLD = 0.001

#USE FOR testing 3 points on a line
NOT_ON = 0
SAME_DIRECTION = 1
OPPOSITE_DIRECTION = -1
RATIO_EPSILON = 0.01

class Location:
    def __init__(self, time, x, y):
        self.time = self.convertToFloat(time)
        self.x = self.convertToFloat(x)
        self.y = self.convertToFloat(y)
        self.distance = 0
        self.turnAngle = 0
        
    def convertToFloat(self, number):
        converted = float(number)
        return (0 if math.isnan(converted) else converted)
        
    def print(self):
        print(self.time, self.x, self.y)
    
    def getInfo(self):
        return f'{self.time}\t{self.x}\t{self.y}'
    
    def getDistance(self, b):
        tx = math.pow((self.x - b.x), 2)
        ty = math.pow((self.y - b.y), 2)
        result = math.pow(tx + ty, 0.5)
        
        return result if result > DISTANCE_THRESHOLD else 0
    
    #Find cos(alpha) at t using t - 1 and t + 1
    #return 
    def getCos(self, p1, p3):
        try:
            d1 = self.getDistance(p1)
            d2 = self.getDistance(p3)
            d3 = p1.getDistance(p3)

            #no movement or small changes
            #need to check direction
            
            if (d1 == 0) or (d2 == 0):
                return -1
            #turn angle will be 180degree for coming back to previous location
            if (d3 == 0):
                return 1
            cosAlpha = (d1 * d1 + d2 * d2 - d3 * d3) / (2 * d1 * d2)
        except Exception as e:
            print(f'ERROR: getting cos at times: {p1.time}, {self.time}, {p3.time}')
            
        return cosAlpha
    
    #check to see if they are in a straight line
    #Return: 0: No, 1: same direction, -1: opposite direction
    def onStraightLine(self, p1, p3):
        try:
            #TODO: division by zero check
            X1 = p1.x - self.x
            Y1 = p1.y - self.y
            X2 = p3.x - self.x
            Y2 = p3.y - self.y
            if (X2 == 0) and (X1 != 0):
                return NOT_ON
            if (Y2 == 0) and (Y1 != 0):
                return NOT_ON
            
            if (X2 == 0):
                k1 = Y1 / Y2
                k2 = k1
            elif (Y1 == 0):
                k1 = X1 / X2
                k2 = k1
            else:
                k1 = X1 / X2
                k2 = Y1 / Y2
            d = abs(k1 - k2)
            if d > RATIO_EPSILON:
                return NOT_ON
            else:
                if k1 < 0:
                    return SAME_DIRECTION
                else:
                    return OPPOSITE_DIRECTION
        except Exception as e:
            print(f'ERROR verifying straightline: {e}\n')
            print(f'{p1.getInfo()}\n{self.getInfo()}\n{p3.getInfo()}\n')
            return 0
        
    def calTurnAngleInRadius(self, p1, p3):
        result = 0
        try:
            isOnLine = self.onStraightLine(p1, p3)
            if isOnLine == SAME_DIRECTION:
                result = 0
            elif isOnLine == OPPOSITE_DIRECTION:
                result = math.pi
            else:
                result = math.pi - math.acos(self.getCos(p1, p3))
                
        except Exception as e:
            
            #errorMsg = f'Error calculate turn-angle at:\n {p1.getInfo()}\n{self.getInfo()}\n{p3.getInfo()}\n\n'
            errorMsg = f'{p1.getInfo()}\n{self.getInfo()}\n{p3.getInfo()}\n'
            print(f'ERROR: calculate turn-angle at:{errorMsg}\n')
            print("\n")
            self.logMathError(errorMsg)

            return 0
        
        self.turnAngle = result
        return result
    
    def getTurnAngleInDegree(self):
        return 180 * self.turnAngle / math.pi
    
    def logMathError(self, error):
        errorFile = "./error-math.txt"
        try:
            with open(errorFile,"a") as f:
                f.write(error)
        except Exception as e:
            print(f'Error writing log to file {errorFile}\n')
            print(f'{e}')

# %% [markdown]
# <table>
#     <tr>
#         <th>Table 1</th>
#         <td>Hee</td>
#     </tr>
#         <tr>
#         <th>Table 2</th>
#         <td>Hee</td>
#     </tr>
# </table>

# %% [markdown]
# ## LocationManager class
#   * load the files of each genotype from the FilterResult in Section 1.
#   * transform the (x,y) coordinate to (distance, turn angle)
#   * save all (distance, turn angle) of a genotype into one file
#
# Example: cantonS, 275 files
# Each filtered file
#  - Before transform with time interval = 1.0s
#
# | Time | X   | Y |
# | --- | --- | --- |
# |0.00| -26.98|3.0417|
# |1|-2.7269|2.995|
# |2|2.7542|2.995|
# |...|...|...|
# |598|...|...|
# |599|0.2451|-4.3645|
#
#  - After transforming:
# (distance_i, turnangle_i) with i in [0,600)
# NOTE: fly(index) is not included in actual result
#
# | fly(index) | distance_0   | turnangle_0 | ... | ... | distance_599 | turnangle_599|
# | --- | --- | --- | --- | --- | --- | --- |
# |1| 0|0| ... | ... |0.00571 | 3.14159|
# |2| 0|0| ... | ... |0.00306|2.78596|
# |3| 0|0| ... | ... |0.00122|2.77905|
# |...|...|...||...|...|...|...|
# |274| 0|0| ... | ... |0.00928|1.14832|
# |275| 0|0| ... | ... |0.01073|3.04171|

# %%
#Class for loading and processing (x,y) -> (distance, turnangle)

class LocationManager:
    def __init__(self):
        self.locations = []
        self.errorPath = "./error-log.txt"
        
    #Read file
    def readData(self, fileName):
        store = [] #List of location
        try:
            with open(fileName) as data:
                for line in data.readlines():
                    tmp = line.split()
                    location = Location(tmp[0], tmp[1], tmp[2])
                    store.append(location)
            print(f'Complete reading data for file: {fileName}')
        except Exception as e:
            print(f'ERROR: while reading file: {fileName}')
            print(e)
        return store
    #calculate distance and turn-angle for locations
    def populateLocation(self):
        locationStack = LifoQueue(maxsize = 3) 
        counter = 0
        for location in self.locations:
            if locationStack.empty():
                locationStack.put(location)
            else:
                l1 = locationStack.get()
                location.distance = location.getDistance(l1)
                #if the position does not change, we place the location back in the stack
                if (location.distance <= DISTANCE_THRESHOLD):
                    locationStack.put(location)
                else:
                    # only has two locations, cannot calculate turn angle
                    if locationStack.empty():
                        locationStack.put(l1)
                        locationStack.put(location)
                    else: #has three locations
                        l2 = l1
                        l1 = locationStack.get()
                        l3 = location
                        l2.turnAngle = l2.calTurnAngleInRadius(l1,l3)
                        #add last two locations to stack
                        locationStack.put(l2)
                        locationStack.put(l3)
    #Write file
    def saveResultTo(self, file_path):
        try:
            with open(file_path, "a") as output:
                myData = ""
                for location in self.locations:
                    myData = f'{round(location.distance, 5)}\t\t{round(location.turnAngle, 5)} ' 
                    output.write(myData)
                output.write('\n')
                print(f'Complete saving result to: {file_path}')
        except Exception as e:
            print(f'ERROR: while writing to file {file_path}')
            print(e)
            self.logError(e)
            
    def logError(self, error):
        try:
            with open(self.errorPath,"a") as f:
                f.write(error)
        except Exception as e:
            print(f'ERROR: writing log to file {self.errorPath}\n')
            print(f'{e}')

# %% [markdown]
# ### Running test cases to validate the calculation

# %%
#Integration Testing to validate calculation result
#Create result for testing
manager = LocationManager()
ROOT_TEST = "./TestCases"
fileName = os.path.join(ROOT_TEST, "test-angle-input.txt")
resultFile = os.path.join(ROOT_TEST, "test-angle-output.txt")
validateFile = os.path.join(ROOT_TEST, "test-angle-validate.txt")
manager.locations = manager.readData(fileName)
manager.populateLocation()
# Out:
# Complete reading data for file: ./TestCases/test-angle-input.txt

# %% [markdown]
# #### If nothing is displayed after running the line below, the calculation is validated

# %%
#Run this to validate turn angle result
# !diff $resultFile $validateFile
#if no line or error printed out, the result are match

# %%
GENOTYPES = ["cantonS","W1118","norpA7","rutabaga"]

# %%
#Create TRANSFORM folders

TRANSFORM_FOLDER = "./TransformSmall"
# !mkdir $TRANSFORM_FOLDER

#create folders for each genotypes
for genotype in GENOTYPES:
    path = os.path.join(TRANSFORM_FOLDER, genotype)
    # !mkdir $path

# %% [markdown]
# * Estimated runtime for the code below - [1 - 2] minutes

# %%
locationManager = LocationManager()
input_path = fileManager.OUTPUT_FOLDER 
for genotype in GENOTYPES:
    data_path = os.path.join(input_path, genotype)
    flyFiles = os.listdir(data_path)
    result_path = os.path.join(TRANSFORM_FOLDER, genotype, genotype+ "_10min.txt")
    for fly in flyFiles:
        try:
            file_path = os.path.join(data_path, fly)
            print(f'Processing file: {file_path}')
            locationManager.locations = locationManager.readData(file_path)
            print(f'Complete reading file: {file_path}')
            
            print(f'Calculating distance and turn angle')
            locationManager.populateLocation()
            
            locationManager.saveResultTo(result_path)
        except Exception as e:
            print(f'ERROR: processing file {file_path}\n')
            print(f'{e}')
# Out:
# Processing file: ./SmallIntervalData/cantonS/run238.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run238.txt
# Complete reading file: ./SmallIntervalData/cantonS/run238.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run204.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run204.txt
# Complete reading file: ./SmallIntervalData/cantonS/run204.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run210.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run210.txt
# Complete reading file: ./SmallIntervalData/cantonS/run210.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run199.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run199.txt
# Complete reading file: ./SmallIntervalData/cantonS/run199.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run172.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run172.txt
# Complete reading file: ./SmallIntervalData/cantonS/run172.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run166.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run166.txt
# Complete reading file: ./SmallIntervalData/cantonS/run166.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run94.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run94.txt
# Complete reading file: ./SmallIntervalData/cantonS/run94.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run80.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run80.txt
# Complete reading file: ./SmallIntervalData/cantonS/run80.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run57.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run57.txt
# Complete reading file: ./SmallIntervalData/cantonS/run57.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run43.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run43.txt
# Complete reading file: ./SmallIntervalData/cantonS/run43.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run42.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run42.txt
# Complete reading file: ./SmallIntervalData/cantonS/run42.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run56.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run56.txt
# Complete reading file: ./SmallIntervalData/cantonS/run56.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run81.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run81.txt
# Complete reading file: ./SmallIntervalData/cantonS/run81.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run95.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run95.txt
# Complete reading file: ./SmallIntervalData/cantonS/run95.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run167.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run167.txt
# Complete reading file: ./SmallIntervalData/cantonS/run167.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run173.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run173.txt
# Complete reading file: ./SmallIntervalData/cantonS/run173.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run198.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run198.txt
# Complete reading file: ./SmallIntervalData/cantonS/run198.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run211.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run211.txt
# Complete reading file: ./SmallIntervalData/cantonS/run211.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run205.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run205.txt
# Complete reading file: ./SmallIntervalData/cantonS/run205.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run239.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run239.txt
# Complete reading file: ./SmallIntervalData/cantonS/run239.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run213.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run213.txt
# Complete reading file: ./SmallIntervalData/cantonS/run213.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run207.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run207.txt
# Complete reading file: ./SmallIntervalData/cantonS/run207.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run159.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run159.txt
# Complete reading file: ./SmallIntervalData/cantonS/run159.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run165.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run165.txt
# Complete reading file: ./SmallIntervalData/cantonS/run165.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run171.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run171.txt
# Complete reading file: ./SmallIntervalData/cantonS/run171.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run83.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run83.txt
# Complete reading file: ./SmallIntervalData/cantonS/run83.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run97.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run97.txt
# Complete reading file: ./SmallIntervalData/cantonS/run97.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run40.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run40.txt
# Complete reading file: ./SmallIntervalData/cantonS/run40.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run54.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run54.txt
# Complete reading file: ./SmallIntervalData/cantonS/run54.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run68.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run68.txt
# Complete reading file: ./SmallIntervalData/cantonS/run68.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run69.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run69.txt
# Complete reading file: ./SmallIntervalData/cantonS/run69.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run55.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run55.txt
# Complete reading file: ./SmallIntervalData/cantonS/run55.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run41.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run41.txt
# Complete reading file: ./SmallIntervalData/cantonS/run41.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run96.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run96.txt
# Complete reading file: ./SmallIntervalData/cantonS/run96.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run82.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run82.txt
# Complete reading file: ./SmallIntervalData/cantonS/run82.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run170.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run170.txt
# Complete reading file: ./SmallIntervalData/cantonS/run170.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run164.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run164.txt
# Complete reading file: ./SmallIntervalData/cantonS/run164.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run158.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run158.txt
# Complete reading file: ./SmallIntervalData/cantonS/run158.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run206.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run206.txt
# Complete reading file: ./SmallIntervalData/cantonS/run206.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run212.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run212.txt
# Complete reading file: ./SmallIntervalData/cantonS/run212.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run216.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run216.txt
# Complete reading file: ./SmallIntervalData/cantonS/run216.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run202.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run202.txt
# Complete reading file: ./SmallIntervalData/cantonS/run202.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run160.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run160.txt
# Complete reading file: ./SmallIntervalData/cantonS/run160.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run174.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run174.txt
# Complete reading file: ./SmallIntervalData/cantonS/run174.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run148.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run148.txt
# Complete reading file: ./SmallIntervalData/cantonS/run148.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run86.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run86.txt
# Complete reading file: ./SmallIntervalData/cantonS/run86.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run92.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run92.txt
# Complete reading file: ./SmallIntervalData/cantonS/run92.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run79.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run79.txt
# Complete reading file: ./SmallIntervalData/cantonS/run79.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run45.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run45.txt
# Complete reading file: ./SmallIntervalData/cantonS/run45.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run51.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run51.txt
# Complete reading file: ./SmallIntervalData/cantonS/run51.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run50.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run50.txt
# Complete reading file: ./SmallIntervalData/cantonS/run50.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run44.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run44.txt
# Complete reading file: ./SmallIntervalData/cantonS/run44.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run78.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run78.txt
# Complete reading file: ./SmallIntervalData/cantonS/run78.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run93.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run93.txt
# Complete reading file: ./SmallIntervalData/cantonS/run93.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run87.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run87.txt
# Complete reading file: ./SmallIntervalData/cantonS/run87.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run149.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run149.txt
# Complete reading file: ./SmallIntervalData/cantonS/run149.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run175.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run175.txt
# Complete reading file: ./SmallIntervalData/cantonS/run175.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run161.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run161.txt
# Complete reading file: ./SmallIntervalData/cantonS/run161.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run203.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run203.txt
# Complete reading file: ./SmallIntervalData/cantonS/run203.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run217.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run217.txt
# Complete reading file: ./SmallIntervalData/cantonS/run217.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run201.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run201.txt
# Complete reading file: ./SmallIntervalData/cantonS/run201.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run215.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run215.txt
# Complete reading file: ./SmallIntervalData/cantonS/run215.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run229.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run229.txt
# Complete reading file: ./SmallIntervalData/cantonS/run229.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run188.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run188.txt
# Complete reading file: ./SmallIntervalData/cantonS/run188.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run177.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run177.txt
# Complete reading file: ./SmallIntervalData/cantonS/run177.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run163.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run163.txt
# Complete reading file: ./SmallIntervalData/cantonS/run163.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run91.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run91.txt
# Complete reading file: ./SmallIntervalData/cantonS/run91.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run85.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run85.txt
# Complete reading file: ./SmallIntervalData/cantonS/run85.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run52.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run52.txt
# Complete reading file: ./SmallIntervalData/cantonS/run52.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run46.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run46.txt
# Complete reading file: ./SmallIntervalData/cantonS/run46.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run47.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run47.txt
# Complete reading file: ./SmallIntervalData/cantonS/run47.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run53.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run53.txt
# Complete reading file: ./SmallIntervalData/cantonS/run53.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run84.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run84.txt
# Complete reading file: ./SmallIntervalData/cantonS/run84.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run90.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run90.txt
# Complete reading file: ./SmallIntervalData/cantonS/run90.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run162.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run162.txt
# Complete reading file: ./SmallIntervalData/cantonS/run162.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run176.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run176.txt
# Complete reading file: ./SmallIntervalData/cantonS/run176.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run189.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run189.txt
# Complete reading file: ./SmallIntervalData/cantonS/run189.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run228.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run228.txt
# Complete reading file: ./SmallIntervalData/cantonS/run228.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run214.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run214.txt
# Complete reading file: ./SmallIntervalData/cantonS/run214.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run200.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run200.txt
# Complete reading file: ./SmallIntervalData/cantonS/run200.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run267.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run267.txt
# Complete reading file: ./SmallIntervalData/cantonS/run267.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run273.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run273.txt
# Complete reading file: ./SmallIntervalData/cantonS/run273.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run139.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run139.txt
# Complete reading file: ./SmallIntervalData/cantonS/run139.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run111.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run111.txt
# Complete reading file: ./SmallIntervalData/cantonS/run111.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run105.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run105.txt
# Complete reading file: ./SmallIntervalData/cantonS/run105.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run34.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run34.txt
# Complete reading file: ./SmallIntervalData/cantonS/run34.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run20.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run20.txt
# Complete reading file: ./SmallIntervalData/cantonS/run20.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run21.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run21.txt
# Complete reading file: ./SmallIntervalData/cantonS/run21.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run35.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run35.txt
# Complete reading file: ./SmallIntervalData/cantonS/run35.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run104.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run104.txt
# Complete reading file: ./SmallIntervalData/cantonS/run104.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run110.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run110.txt
# Complete reading file: ./SmallIntervalData/cantonS/run110.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run138.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run138.txt
# Complete reading file: ./SmallIntervalData/cantonS/run138.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run272.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run272.txt
# Complete reading file: ./SmallIntervalData/cantonS/run272.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run266.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run266.txt
# Complete reading file: ./SmallIntervalData/cantonS/run266.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run258.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run258.txt
# Complete reading file: ./SmallIntervalData/cantonS/run258.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run270.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run270.txt
# Complete reading file: ./SmallIntervalData/cantonS/run270.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run264.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run264.txt
# Complete reading file: ./SmallIntervalData/cantonS/run264.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run106.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run106.txt
# Complete reading file: ./SmallIntervalData/cantonS/run106.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run112.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run112.txt
# Complete reading file: ./SmallIntervalData/cantonS/run112.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run23.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run23.txt
# Complete reading file: ./SmallIntervalData/cantonS/run23.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run37.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run37.txt
# Complete reading file: ./SmallIntervalData/cantonS/run37.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run36.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run36.txt
# Complete reading file: ./SmallIntervalData/cantonS/run36.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run22.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run22.txt
# Complete reading file: ./SmallIntervalData/cantonS/run22.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run113.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run113.txt
# Complete reading file: ./SmallIntervalData/cantonS/run113.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run107.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run107.txt
# Complete reading file: ./SmallIntervalData/cantonS/run107.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run265.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run265.txt
# Complete reading file: ./SmallIntervalData/cantonS/run265.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run271.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run271.txt
# Complete reading file: ./SmallIntervalData/cantonS/run271.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run259.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run259.txt
# Complete reading file: ./SmallIntervalData/cantonS/run259.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run275.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run275.txt
# Complete reading file: ./SmallIntervalData/cantonS/run275.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run261.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run261.txt
# Complete reading file: ./SmallIntervalData/cantonS/run261.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run249.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run249.txt
# Complete reading file: ./SmallIntervalData/cantonS/run249.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run9.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run9.txt
# Complete reading file: ./SmallIntervalData/cantonS/run9.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run103.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run103.txt
# Complete reading file: ./SmallIntervalData/cantonS/run103.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run117.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run117.txt
# Complete reading file: ./SmallIntervalData/cantonS/run117.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run26.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run26.txt
# Complete reading file: ./SmallIntervalData/cantonS/run26.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run32.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run32.txt
# Complete reading file: ./SmallIntervalData/cantonS/run32.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run33.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run33.txt
# Complete reading file: ./SmallIntervalData/cantonS/run33.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run27.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run27.txt
# Complete reading file: ./SmallIntervalData/cantonS/run27.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run116.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run116.txt
# Complete reading file: ./SmallIntervalData/cantonS/run116.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run102.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run102.txt
# Complete reading file: ./SmallIntervalData/cantonS/run102.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run8.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run8.txt
# Complete reading file: ./SmallIntervalData/cantonS/run8.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run248.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run248.txt
# Complete reading file: ./SmallIntervalData/cantonS/run248.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run260.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run260.txt
# Complete reading file: ./SmallIntervalData/cantonS/run260.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run274.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run274.txt
# Complete reading file: ./SmallIntervalData/cantonS/run274.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run262.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run262.txt
# Complete reading file: ./SmallIntervalData/cantonS/run262.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run276.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run276.txt
# Complete reading file: ./SmallIntervalData/cantonS/run276.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run114.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run114.txt
# Complete reading file: ./SmallIntervalData/cantonS/run114.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run100.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run100.txt
# Complete reading file: ./SmallIntervalData/cantonS/run100.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run128.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run128.txt
# Complete reading file: ./SmallIntervalData/cantonS/run128.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run19.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run19.txt
# Complete reading file: ./SmallIntervalData/cantonS/run19.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run31.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run31.txt
# Complete reading file: ./SmallIntervalData/cantonS/run31.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run25.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run25.txt
# Complete reading file: ./SmallIntervalData/cantonS/run25.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run30.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run30.txt
# Complete reading file: ./SmallIntervalData/cantonS/run30.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run18.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run18.txt
# Complete reading file: ./SmallIntervalData/cantonS/run18.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run129.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run129.txt
# Complete reading file: ./SmallIntervalData/cantonS/run129.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run101.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run101.txt
# Complete reading file: ./SmallIntervalData/cantonS/run101.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run115.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run115.txt
# Complete reading file: ./SmallIntervalData/cantonS/run115.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run263.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run263.txt
# Complete reading file: ./SmallIntervalData/cantonS/run263.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run246.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run246.txt
# Complete reading file: ./SmallIntervalData/cantonS/run246.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run252.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run252.txt
# Complete reading file: ./SmallIntervalData/cantonS/run252.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run6.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run6.txt
# Complete reading file: ./SmallIntervalData/cantonS/run6.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run118.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run118.txt
# Complete reading file: ./SmallIntervalData/cantonS/run118.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run130.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run130.txt
# Complete reading file: ./SmallIntervalData/cantonS/run130.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run124.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run124.txt
# Complete reading file: ./SmallIntervalData/cantonS/run124.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run15.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run15.txt
# Complete reading file: ./SmallIntervalData/cantonS/run15.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run29.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run29.txt
# Complete reading file: ./SmallIntervalData/cantonS/run29.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run28.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run28.txt
# Complete reading file: ./SmallIntervalData/cantonS/run28.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run14.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run14.txt
# Complete reading file: ./SmallIntervalData/cantonS/run14.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run125.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run125.txt
# Complete reading file: ./SmallIntervalData/cantonS/run125.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run131.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run131.txt
# Complete reading file: ./SmallIntervalData/cantonS/run131.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run119.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run119.txt
# Complete reading file: ./SmallIntervalData/cantonS/run119.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run7.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run7.txt
# Complete reading file: ./SmallIntervalData/cantonS/run7.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run253.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run253.txt
# Complete reading file: ./SmallIntervalData/cantonS/run253.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run247.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run247.txt
# Complete reading file: ./SmallIntervalData/cantonS/run247.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run251.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run251.txt
# Complete reading file: ./SmallIntervalData/cantonS/run251.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run245.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run245.txt
# Complete reading file: ./SmallIntervalData/cantonS/run245.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run5.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run5.txt
# Complete reading file: ./SmallIntervalData/cantonS/run5.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run127.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run127.txt
# Complete reading file: ./SmallIntervalData/cantonS/run127.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run133.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run133.txt
# Complete reading file: ./SmallIntervalData/cantonS/run133.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run16.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run16.txt
# Complete reading file: ./SmallIntervalData/cantonS/run16.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run17.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run17.txt
# Complete reading file: ./SmallIntervalData/cantonS/run17.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run132.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run132.txt
# Complete reading file: ./SmallIntervalData/cantonS/run132.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run126.txt
# Complete reading data for file: ./SmallIntervalData/cantonS/run126.txt
# Complete reading file: ./SmallIntervalData/cantonS/run126.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/cantonS/cantonS_10min.txt
# Processing file: ./SmallIntervalData/cantonS/run4.txt
# ...
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    44).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    45).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    45).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    45).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    33).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    33).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    33).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    32).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    32).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    32).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    10).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    10).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    10).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    11).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    11).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    11).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    59).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    59).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    59).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    58).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    58).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    58).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     8).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     8).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     8).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     9).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     9).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     9).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    53).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    53).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    53).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    52).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    52).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    52).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     2).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     2).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     2).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     3).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     3).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     3).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    24).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    24).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    24).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    25).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    25).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    25).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    17).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    17).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    17).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    16).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    16).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    16).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    29).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    29).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    29).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    28).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    28).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    28).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    60).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    60).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    60).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    54).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    54).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    54).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    55).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    55).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    55).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     5).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     5).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     5).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     4).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     4).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial     4).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    23).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    23).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    23).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    22).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    22).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    22).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    49).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    49).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    49).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    48).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    48).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    48).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    43).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    43).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    43).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    42).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    42).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    42).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    34).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    34).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    34).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt
# Processing file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    35).xls.txt
# Complete reading data for file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    35).xls.txt
# Complete reading file: ./SmallIntervalData/rutabaga/rutabaga in 8_4 circular arena Benjamin-Nov 16, 2011 (Trial    35).xls.txt
# Calculating distance and turn angle
# Complete saving result to: ./TransformSmall/rutabaga/rutabaga_10min.txt

# %% [markdown]
# * Verify that we have all the needed files by running the code below
# * Your Transform folder should contain folder of each genotype.
# * Each genotype's folder should have one file with format <genotype_10min.txt>

# %%
# !ls -AR ./TransformSmall/
# Out:
# W1118    cantonS  norpA7   rutabaga
#
# ./TransformSmall//W1118:
# W1118_10min.txt
#
# ./TransformSmall//cantonS:
# cantonS_10min.txt
#
# ./TransformSmall//norpA7:
# norpA7_10min.txt
#
# ./TransformSmall//rutabaga:
# rutabaga_10min.txt

# %% [markdown]
# * Verify that we have 1200 columns for each genotype

# %%
NB_COLUMNS = 1200
for genotype in GENOTYPES:
    dataPath = os.path.join(TRANSFORM_FOLDER, genotype, genotype + "_10min.txt")
    with open(dataPath, "r") as inputData:
        line = inputData.readline()
        print(f'{genotype} has {NB_COLUMNS} ? {len(line.split()) == NB_COLUMNS}')
# Out:
# cantonS has 1200 ? False
# W1118 has 1200 ? False
# norpA7 has 1200 ? False
# rutabaga has 1200 ? False

# %% [markdown]
# ## 3. Partition files
# After converting the recorded data to (distance, turn angle) of 10-minute records, we will split the data into 4 different partitions: first 2.5-minute, first 5-minute, last 5-minute, last 2.5-minute

# %%
partitions = [("_first_2.5min", 0, 300), ("_first_5min",0, 600), ("_last_5min",600, 1200), 
              ("_last_2.5min", 900, 1200)]

# %%
#interval 0.2
partitions = [("_first_2.5min", 0, 1500), ("_first_5min",0, 3000), ("_last_5min",3000, 6000), 
              ("_last_2.5min", 4500, 6000)]

# %%
ROOT = TRANSFORM_FOLDER
fileType = ".txt"

# %% [markdown]
# * Estimate runtime for partitioning: 20 seconds

# %%
for partition in partitions:
    (partitionName, fromSecond, toSecond) = partition
    for genotype in GENOTYPES:
        #prepare paths for read and write
        inFile = genotype + "_10min" + fileType
        inPath = os.path.join(ROOT, genotype, inFile)
        
        outFile = genotype + partitionName + fileType
        outPath = os.path.join(ROOT, genotype, outFile)
        
        #start reading and writing concurrently
        with open(inPath, "r") as inputData, open(outPath, "w") as output:
            for line in inputData.readlines():
                data = line.split()
                counter = fromSecond
                while counter < toSecond:
                    column = data[counter]
                    output.write(column)
                    output.write(" ")
                    counter += 1
                output.write("\n")

# %% [markdown]
# * Verify that we have all the needed files by running the code below
# * Your Transform folder should contain folder of each genotype.
# * Now, each genotype's folder should have 5 files with their names followed the format <genotype_10min.txt>, <genotype_first_2.5min.txt>, <genotype_first_5min.txt> , <genotype_last_5min.txt> <genotype_last_2.5min.txt>

# %%
# !ls -AR ./TransformSmall/
# Out:
# W1118    cantonS  norpA7   rutabaga
#
# ./TransformSmall//W1118:
# W1118_10min.txt        W1118_first_5min.txt   W1118_last_5min.txt
# W1118_first_2.5min.txt W1118_last_2.5min.txt
#
# ./TransformSmall//cantonS:
# cantonS_10min.txt        cantonS_first_5min.txt   cantonS_last_5min.txt
# cantonS_first_2.5min.txt cantonS_last_2.5min.txt
#
# ./TransformSmall//norpA7:
# norpA7_10min.txt        norpA7_first_5min.txt   norpA7_last_5min.txt
# norpA7_first_2.5min.txt norpA7_last_2.5min.txt
#
# ./TransformSmall//rutabaga:
# rutabaga_10min.txt        rutabaga_first_5min.txt   rutabaga_last_5min.txt
# rutabaga_first_2.5min.txt rutabaga_last_2.5min.txt
